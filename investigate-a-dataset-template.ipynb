# %% [markdown]
# # Project: TMDb movie data analysis
#
# ## Table of Contents
# <ul>
# <li><a href="#intro">Introduction</a></li>
# <li><a href="#wrangling">Data Wrangling</a></li>
# <li><a href="#eda">Exploratory Data Analysis</a></li>
# <li><a href="#conclusions">Conclusions</a></li>
# </ul>

# %% [markdown]
# <a id='intro'></a>
# ## Introduction
#
# I choose the TMDb movie data set for data analysis. This data set contains information about 10,000 movies collected from The Movie Database (TMDb) from 1960 to 2015, including user ratings, budget and revenue.I would like to find other intresting patterns in the dataset.
#
# ### Dataset Description
#
# 1. id - The id number of the movie in the TMDb.
# 2. imdb_id - The internet movie database id number.
# 3. popularity - The number of people that know or watch the movies.
# 4. budget - The money estimate set aside for the movie production.
# 5. revenue - The money made from the movie.
# 6. original_title - The title of the movie.
# 7. cast - The name of the actor/actress in the movie.
# 8. homepage - The website address of the movie.
# 9. director - The name of the movie director.
# 10. tagline - These are slogans or catchphrases for films.
# 11. keyword - These are the words you type into a search box to find information.
# 12. overview - This is a general summary/short story of what the movie is all about.
# 13. runtime - This is the amount of time it takes for a film to be shown from beginning to end in one sitting.
# 14. genres - This is simply a category that films belong to based on their subject matter, tone, and other factors.
# 15. production_companies - This is the company/organization that produce the company.
# 16. release_date - The date at which the movie was release.
# 17. vote_count -This is the amount of rating the movie was given.
# 18. vote_average - It's the average of all of the TMDb user ratings. We don't import a rating from anyone.
# 19. release_year - The year in which the movie was release.
# 20. budget_adj - This is the adjusted budget.
# 21. revenue_adj - This is the adjusted revenue.

# %%
#importing python packages that i would use for my analysis
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# <a id='wrangling'></a>
# ## Data Wrangling
#
# In this section of the report, I will loading my data, check for cleanliness, and then clean my dataset for my analysis.
#
#
# ### General Properties
#
# Total Rows = 10866
# Total Columns = 21
# After Seeing the dataset we can say that some columns is contain null values

# %%
#Load the dataset
#print/review the last 5 row of the dataset
df= pd.read_csv('tmdb-movies.csv')
df.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# 0                      http://www.jurassicworld.com/   Colin Trevorrow
# 1                        http://www.madmaxmovie.com/     George Miller
# 2     http://www.thedivergentseries.movie/#insurgent  Robert Schwentke
# 3  http://www.starwars.com/films/star-wars-episod...       J.J. Abrams
# 4                           http://www.furious7.com/         James Wan
#
#                          tagline  ...  \
# 0              The park is open.  ...
# 1             What a Lovely Day.  ...
# 2     One Choice Can Destroy You  ...
# 3  Every generation has a story.  ...
# 4            Vengeance Hits Home  ...
#
#                                             overview runtime  \
# 0  Twenty-two years after the events of Jurassic ...     124
# 1  An apocalyptic story set in the furthest reach...     120
# 2  Beatrice Prior must confront her inner demons ...     119
# 3  Thirty years after defeating the Galactic Empi...     136
# 4  Deckard Shaw seeks revenge against Dominic Tor...     137
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
# 2         Adventure|Science Fiction|Thriller
# 3   Action|Adventure|Science Fiction|Fantasy
# 4                      Action|Crime|Thriller
#
#                                 production_companies release_date vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...       6/9/15       5562
# 1  Village Roadshow Pictures|Kennedy Miller Produ...      5/13/15       6185
# 2  Summit Entertainment|Mandeville Films|Red Wago...      3/18/15       2480
# 3          Lucasfilm|Truenorth Productions|Bad Robot     12/15/15       5292
# 4  Universal Pictures|Original Film|Media Rights ...       4/1/15       2947
#
#    vote_average  release_year    budget_adj   revenue_adj
# 0           6.5          2015  1.379999e+08  1.392446e+09
# 1           7.1          2015  1.379999e+08  3.481613e+08
# 2           6.3          2015  1.012000e+08  2.716190e+08
# 3           7.5          2015  1.839999e+08  1.902723e+09
# 4           7.3          2015  1.747999e+08  1.385749e+09
#
# [5 rows x 21 columns]

# %%
#print/review the last 5 row of the dataset
df.tail()
# Out:
#           id    imdb_id  popularity  budget  revenue  \
# 10861     21  tt0060371    0.080598       0        0
# 10862  20379  tt0060472    0.065543       0        0
# 10863  39768  tt0060161    0.065141       0        0
# 10864  21449  tt0061177    0.064317       0        0
# 10865  22293  tt0060666    0.035919   19000        0
#
#                  original_title  \
# 10861        The Endless Summer
# 10862                Grand Prix
# 10863       Beregis Avtomobilya
# 10864    What's Up, Tiger Lily?
# 10865  Manos: The Hands of Fate
#
#                                                     cast homepage  \
# 10861  Michael Hynson|Robert August|Lord 'Tally Ho' B...      NaN
# 10862  James Garner|Eva Marie Saint|Yves Montand|Tosh...      NaN
# 10863  Innokentiy Smoktunovskiy|Oleg Efremov|Georgi Z...      NaN
# 10864  Tatsuya Mihashi|Akiko Wakabayashi|Mie Hama|Joh...      NaN
# 10865  Harold P. Warren|Tom Neyman|John Reynolds|Dian...      NaN
#
#                  director                                            tagline  \
# 10861         Bruce Brown                                                NaN
# 10862  John Frankenheimer  Cinerama sweeps YOU into a drama of speed and ...
# 10863      Eldar Ryazanov                                                NaN
# 10864         Woody Allen                          WOODY ALLEN STRIKES BACK!
# 10865    Harold P. Warren       It's Shocking! It's Beyond Your Imagination!
#
#        ...                                           overview runtime  \
# 10861  ...  The Endless Summer, by Bruce Brown, is one of ...      95
# 10862  ...  Grand Prix driver Pete Aron is fired by his te...     176
# 10863  ...  An insurance agent who moonlights as a carthie...      94
# 10864  ...  In comic Woody Allen's film debut, he took the...      80
# 10865  ...  A family gets lost on the road and stumbles up...      74
#
#                        genres  \
# 10861             Documentary
# 10862  Action|Adventure|Drama
# 10863          Mystery|Comedy
# 10864           Action|Comedy
# 10865                  Horror
#
#                                     production_companies release_date  \
# 10861                                  Bruce Brown Films      6/15/66
# 10862  Cherokee Productions|Joel Productions|Douglas ...     12/21/66
# 10863                                            Mosfilm       1/1/66
# 10864                            Benedict Pictures Corp.      11/2/66
# 10865                                          Norm-Iris     11/15/66
#
#       vote_count  vote_average  release_year     budget_adj  revenue_adj
# 10861         11           7.4          1966       0.000000          0.0
# 10862         20           5.7          1966       0.000000          0.0
# 10863         11           6.5          1966       0.000000          0.0
# 10864         22           5.4          1966       0.000000          0.0
# 10865         15           1.5          1966  127642.279154          0.0
#
# [5 rows x 21 columns]

# %%
#to check/know to number of row and column 
df.shape
# Out:
# (10866, 21)

# %%
#print the Summary of the dataset 
df.describe()
# Out:
#                   id    popularity        budget       revenue       runtime  \
# count   10866.000000  10866.000000  1.086600e+04  1.086600e+04  10866.000000
# mean    66064.177434      0.646441  1.462570e+07  3.982332e+07    102.070863
# std     92130.136561      1.000185  3.091321e+07  1.170035e+08     31.381405
# min         5.000000      0.000065  0.000000e+00  0.000000e+00      0.000000
# 25%     10596.250000      0.207583  0.000000e+00  0.000000e+00     90.000000
# 50%     20669.000000      0.383856  0.000000e+00  0.000000e+00     99.000000
# 75%     75610.000000      0.713817  1.500000e+07  2.400000e+07    111.000000
# max    417859.000000     32.985763  4.250000e+08  2.781506e+09    900.000000
#
#          vote_count  vote_average  release_year    budget_adj   revenue_adj
# count  10866.000000  10866.000000  10866.000000  1.086600e+04  1.086600e+04
# mean     217.389748      5.974922   2001.322658  1.755104e+07  5.136436e+07
# std      575.619058      0.935142     12.812941  3.430616e+07  1.446325e+08
# min       10.000000      1.500000   1960.000000  0.000000e+00  0.000000e+00
# 25%       17.000000      5.400000   1995.000000  0.000000e+00  0.000000e+00
# 50%       38.000000      6.000000   2006.000000  0.000000e+00  0.000000e+00
# 75%      145.750000      6.600000   2011.000000  2.085325e+07  3.369710e+07
# max     9767.000000      9.200000   2015.000000  4.250000e+08  2.827124e+09

# %%
#this returns the number of unique values for each column.
df.nunique()
# Out:
# id                      10865
# imdb_id                 10855
# popularity              10814
# budget                    557
# revenue                  4702
# original_title          10571
# cast                    10719
# homepage                 2896
# director                 5067
# tagline                  7997
# keywords                 8804
# overview                10847
# runtime                   247
# genres                   2039
# production_companies     7445
# release_date             5909
# vote_count               1289
# vote_average               72
# release_year               56
# budget_adj               2614
# revenue_adj              4840
# dtype: int64

# %%
#sum of duplicated row 
sum(df.duplicated())
# Out:
# 1

# %%
# to inspect dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
#  15  release_date          10866 non-null  object
#  16  vote_count            10866 non-null  int64
#  17  vote_average          10866 non-null  float64
#  18  release_year          10866 non-null  int64
#  19  budget_adj            10866 non-null  float64
#  20  revenue_adj           10866 non-null  float64
# dtypes: float64(4), int64(6), object(11)
# memory usage: 1.7+ MB

# %%
#review/print sum of null values 
df.isnull().sum()
# Out:
# id                         0
# imdb_id                   10
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      76
# homepage                7930
# director                  44
# tagline                 2824
# keywords                1493
# overview                   4
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64

# %% [markdown]
# After carefully inspecting and assessing my data. I discovered the following:
#
# 1. One duplicate
# 2. Null values
# 3. The release date is not in date-time format
# 4. My genres column contain multiples genres for each movie seperated by '|'
# 5. I dont need some columns for my analysis

# %% [markdown]
# ## Data Cleaning
#
# In this session of my analysis, I will be addressing and fixing the following:
#
# 1. Dropping the columns i wont be using for my analysis
# 2. Change release_date to date_time format
# 3. fill null values
# 4. splitting the genre in the column

# %%
#i drop row which i didn't need and which contain incorrect values
df.drop(['imdb_id','homepage','cast','tagline','keywords','overview'], axis=1, inplace= True)

# %%
#drop this row also
df.drop(['production_companies'], axis=1, inplace=True)

# %%
# review the first 5 row of the remaining column 
df.head()
# Out:
#        id  popularity     budget     revenue                original_title  \
# 0  135397   32.985763  150000000  1513528810                Jurassic World
# 1   76341   28.419936  150000000   378436354            Mad Max: Fury Road
# 2  262500   13.112507  110000000   295238201                     Insurgent
# 3  140607   11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4  168259    9.335014  190000000  1506249360                     Furious 7
#
#            director  runtime                                     genres  \
# 0   Colin Trevorrow      124  Action|Adventure|Science Fiction|Thriller
# 1     George Miller      120  Action|Adventure|Science Fiction|Thriller
# 2  Robert Schwentke      119         Adventure|Science Fiction|Thriller
# 3       J.J. Abrams      136   Action|Adventure|Science Fiction|Fantasy
# 4         James Wan      137                      Action|Crime|Thriller
#
#   release_date  vote_count  vote_average  release_year    budget_adj  \
# 0       6/9/15        5562           6.5          2015  1.379999e+08
# 1      5/13/15        6185           7.1          2015  1.379999e+08
# 2      3/18/15        2480           6.3          2015  1.012000e+08
# 3     12/15/15        5292           7.5          2015  1.839999e+08
# 4       4/1/15        2947           7.3          2015  1.747999e+08
#
#     revenue_adj
# 0  1.392446e+09
# 1  3.481613e+08
# 2  2.716190e+08
# 3  1.902723e+09
# 4  1.385749e+09

# %%
#i changed the release_date format to datetime format
df['release_date']= pd.to_datetime(df['release_date'])

# %%
# review the first row of the remaining column
df.head(1)
# Out:
#        id  popularity     budget     revenue  original_title         director  \
# 0  135397   32.985763  150000000  1513528810  Jurassic World  Colin Trevorrow
#
#    runtime                                     genres release_date  \
# 0      124  Action|Adventure|Science Fiction|Thriller   2015-06-09
#
#    vote_count  vote_average  release_year    budget_adj   revenue_adj
# 0        5562           6.5          2015  1.379999e+08  1.392446e+09

# %%
#After removing unused columns, i have (row:10866, columns:14 )
df.shape
# Out:
# (10866, 14)

# %%
#review information about the remaining columns in dataset, director and genres column have missing values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              10866 non-null  int64
#  1   popularity      10866 non-null  float64
#  2   budget          10866 non-null  int64
#  3   revenue         10866 non-null  int64
#  4   original_title  10866 non-null  object
#  5   director        10822 non-null  object
#  6   runtime         10866 non-null  int64
#  7   genres          10843 non-null  object
#  8   release_date    10866 non-null  datetime64[ns]
#  9   vote_count      10866 non-null  int64
#  10  vote_average    10866 non-null  float64
#  11  release_year    10866 non-null  int64
#  12  budget_adj      10866 non-null  float64
#  13  revenue_adj     10866 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int64(6), object(3)
# memory usage: 1.2+ MB

# %%
#fill missing values for director column
df['director']= df['director'].fillna(method= 'ffill')

# %%
#fill missing values for genres columns
df['genres']= df['genres'].fillna(method= 'ffill')

# %%
#review dataset again to confirm if missing value has been fixed
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              10866 non-null  int64
#  1   popularity      10866 non-null  float64
#  2   budget          10866 non-null  int64
#  3   revenue         10866 non-null  int64
#  4   original_title  10866 non-null  object
#  5   director        10866 non-null  object
#  6   runtime         10866 non-null  int64
#  7   genres          10866 non-null  object
#  8   release_date    10866 non-null  datetime64[ns]
#  9   vote_count      10866 non-null  int64
#  10  vote_average    10866 non-null  float64
#  11  release_year    10866 non-null  int64
#  12  budget_adj      10866 non-null  float64
#  13  revenue_adj     10866 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int64(6), object(3)
# memory usage: 1.2+ MB

# %%
#i have 4 string combines in the genre column so i splited the genre column and picked the first object in the genre column,
#so as to make it eazy and efficient for me to work with.
df['genres'] = df.genres.astype('str').apply(lambda x: x.split('|')[0])

# %%
#review my first 5 dataset to see if the split has been applied 
df.head()
# Out:
#        id  popularity     budget     revenue                original_title  \
# 0  135397   32.985763  150000000  1513528810                Jurassic World
# 1   76341   28.419936  150000000   378436354            Mad Max: Fury Road
# 2  262500   13.112507  110000000   295238201                     Insurgent
# 3  140607   11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4  168259    9.335014  190000000  1506249360                     Furious 7
#
#            director  runtime     genres release_date  vote_count  \
# 0   Colin Trevorrow      124     Action   2015-06-09        5562
# 1     George Miller      120     Action   2015-05-13        6185
# 2  Robert Schwentke      119  Adventure   2015-03-18        2480
# 3       J.J. Abrams      136     Action   2015-12-15        5292
# 4         James Wan      137     Action   2015-04-01        2947
#
#    vote_average  release_year    budget_adj   revenue_adj
# 0           6.5          2015  1.379999e+08  1.392446e+09
# 1           7.1          2015  1.379999e+08  3.481613e+08
# 2           6.3          2015  1.012000e+08  2.716190e+08
# 3           7.5          2015  1.839999e+08  1.902723e+09
# 4           7.3          2015  1.747999e+08  1.385749e+09

# %%
#dropping duplicateed row
df.drop_duplicates(inplace= True)

# %%
#i have no duplicated row anymore in my dataset
df.duplicated().sum()
# Out:
# 0

# %%
#This is the mean quality of each movie genre with groupby
df.groupby('genres').mean()
# Out:
#                             id  popularity        budget       revenue  \
# genres
# Action            47673.471402    0.835974  2.463101e+07  6.072035e+07
# Adventure         45114.796928    1.217868  4.023351e+07  1.247560e+08
# Animation         59918.623762    0.808415  2.143920e+07  7.127982e+07
# Comedy            51093.879088    0.536468  1.035624e+07  2.923944e+07
# Crime             54032.269634    0.690887  1.331987e+07  3.326126e+07
# Documentary      125283.572748    0.176806  4.298327e+05  1.968156e+06
# Drama             64679.169581    0.551517  1.030236e+07  2.508268e+07
# Family            95033.848276    0.726208  1.822682e+07  6.106519e+07
# Fantasy           44629.816176    0.865390  2.344872e+07  6.729393e+07
# Foreign           35262.888889    0.167124  0.000000e+00  0.000000e+00
# History          128409.181818    0.764636  1.593452e+07  4.436062e+07
# Horror            75028.562227    0.468203  5.611203e+06  1.684785e+07
# Music             92376.440000    0.447730  1.052200e+07  2.304616e+07
# Mystery           82097.336000    0.596896  1.010633e+07  2.415905e+07
# Romance          120655.155914    0.704157  1.113169e+07  3.788650e+07
# Science Fiction   83732.597222    1.065290  2.487899e+07  7.891853e+07
# TV Movie         110971.430380    0.246170  2.468354e+05  5.316456e+05
# Thriller         125147.949187    0.672149  1.216008e+07  2.642941e+07
# War               90521.372881    0.767041  2.283407e+07  4.590766e+07
# Western           53975.488372    0.682589  1.906323e+07  3.036790e+07
#
#                     runtime  vote_count  vote_average  release_year  \
# genres
# Action           104.218730  338.829038      5.753614   1999.327467
# Adventure        108.522184  555.662116      6.052048   1998.546075
# Animation         64.883663  283.383663      6.416337   2004.059406
# Comedy            97.491824  141.753873      5.885757   2000.766781
# Crime            108.306283  226.361257      6.215707   1999.308901
# Documentary      103.900693   34.600462      6.923557   2008.124711
# Drama            111.818219  165.032940      6.201464   2001.838959
# Family            85.131034  214.337931      5.942069   2003.793103
# Fantasy          100.227941  316.018382      5.795956   1998.930147
# Foreign          110.888889   20.333333      5.900000   2004.222222
# History          133.250000  246.340909      6.381818   2003.840909
# Horror            92.985808  121.684498      5.318777   2000.896288
# Music            108.070000   94.090000      6.605000   2002.360000
# Mystery          102.640000  159.560000      5.900800   2000.200000
# Romance          103.413978  217.607527      6.133871   2004.365591
# Science Fiction   98.546296  507.300926      5.962963   2001.208333
# TV Movie          89.759494   28.594937      5.797468   2004.227848
# Thriller         101.845528  207.087398      5.636992   2005.603659
# War              129.372881  259.796610      6.183051   1999.372881
# Western          113.139535  180.465116      6.009302   1986.302326
#
#                    budget_adj   revenue_adj
# genres
# Action           2.945587e+07  7.396355e+07
# Adventure        4.829798e+07  1.665356e+08
# Animation        2.290254e+07  7.652454e+07
# Comedy           1.243779e+07  3.829509e+07
# Crime            1.631158e+07  4.662151e+07
# Documentary      4.749775e+05  2.145159e+06
# Drama            1.298335e+07  3.569891e+07
# Family           2.046222e+07  7.671589e+07
# Fantasy          2.729390e+07  8.283760e+07
# Foreign          0.000000e+00  0.000000e+00
# History          2.318089e+07  6.536195e+07
# Horror           7.069313e+06  2.415339e+07
# Music            1.392836e+07  3.807907e+07
# Mystery          1.242823e+07  3.002289e+07
# Romance          1.286704e+07  4.721514e+07
# Science Fiction  2.971333e+07  9.859663e+07
# TV Movie         2.967818e+05  7.391026e+05
# Thriller         1.364363e+07  3.090629e+07
# War              2.556366e+07  4.874310e+07
# Western          2.566029e+07  4.620722e+07

# %% [markdown]
# <a id='eda'></a>
# ## Exploratory Data Analysis
#
# Now that I've trimmed and cleaned your data, I will be moving on to exploration. I'm  going to be using visualizations to answer some question that i posed below, also I will be looking for between variables
#
# ### Research Question 1 (Which year was movies released the most !)

# %%
df.groupby('release_year').agg({'id':'count'}).sort_values('id',ascending= False).plot(kind= 'bar', figsize= (20,10));

#setup the title and labels of the figure.
plt.title("Most Release Year",fontsize = 14)
plt.xlabel('Release year',fontsize = 13)

#setup the figure size.
sns.set(rc={'figure.figsize':(20,10)})
sns.set_style("whitegrid")

# %% [markdown]
# According to this bar chart, i was able to conclude that movies was release most in 2014,with over 700 movies

# %%
df.budget.hist();

#setup the title of the figure.
plt.title("A Budget Histogram Distribution Chart",fontsize = 14);

# %% [markdown]
# This is a budget histogram distribution and it is not normally distributed.

# %% [markdown]
# ### Research Question 2  (Which Year Has The Highest budget ?)

# %%
df.groupby('release_year')['budget'].mean().plot()

#setup the title and labels of the figure.
plt.title("Year Vs budget",fontsize = 14)
plt.xlabel('Release year',fontsize = 13)
plt.ylabel('budget',fontsize = 13)

#setup the figure size.
sns.set(rc={'figure.figsize':(20,10)})
sns.set_style("whitegrid")

# %% [markdown]
# According to the plot year more that 2 billion was spent on movies made in 1997-2005 than any other year, so the budget for the movies in these years are high

# %% [markdown]
# ### Research Question   (Which Movie genre is most sorted after  ?)

# %%
df.groupby('genres').agg({'id':'count'}).sort_values('id',ascending= False).plot(kind= 'bar', figsize= (20,10));

#setup the title and labels of the figure.
plt.title("Most Sorted Genre",fontsize = 14)
plt.xlabel("Genre's",fontsize = 13)

#setup the figure size.
sns.set(rc={'figure.figsize':(20,10)})
sns.set_style("whitegrid")

# %% [markdown]
# According this plot, Drama movies is the most popular genre, following by comedy, action and horror

# %% [markdown]
# <a id='conclusions'></a>
# ## Conclusions

# %% [markdown]
# After analyzing the TMDb Movie Dataset, i can now come to the decision that:
# 1. 2014 has the highest number of movies released with over 700 movies.
# 2. The budget for 1997-2005 was very high compared to others.
# 3. Drama is the most popular genre, following by comedy, action, horror and adventure.
#
# Limitation
# > During the data cleaning process, I split the genre column seperated it by '|' for easy parsing during the exploration phase. This increases the time taken in calculating the result.
